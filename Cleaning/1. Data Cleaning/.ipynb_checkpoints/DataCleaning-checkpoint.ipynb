# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)

import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %% [markdown]
# # Example of Dropna
# With self made data set

# %%
import numpy as np
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                  "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                    "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT], "Age":['a', 98, np.nan]})
df
# Out:
#        name        toy       born  Age
# 0    Alfred        NaN        NaT    a
# 1    Batman  Batmobile 1940-04-25   98
# 2  Catwoman   Bullwhip        NaT  NaN

# %%
plt.plot(df.Age) # Plotting the age will reveal that there is something wrong!
# See the error below: --> 188                 raise TypeError("{val!r} is not a string".format(val=val))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-7311426ae2b4> in <module>
# ----> 1 plt.plot(df.Age) # Plotting the age will reveal that there is something wrong!
#       2 # See the error below: --> 188                 raise TypeError("{val!r} is not a string".format(val=val))
#
# c:\anaconda3\envs\traineeship\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# c:\anaconda3\envs\traineeship\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# c:\anaconda3\envs\traineeship\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# c:\anaconda3\envs\traineeship\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# c:\anaconda3\envs\traineeship\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     242         if self.axes.xaxis is not None and self.axes.yaxis is not None:
#     243             bx = self.axes.xaxis.update_units(x)
# --> 244             by = self.axes.yaxis.update_units(y)
#     245
#     246             if self.command != 'plot':
#
# c:\anaconda3\envs\traineeship\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1492         neednew = self.converter != converter
#    1493         self.converter = converter
# -> 1494         default = self.converter.default_units(data, self)
#    1495         if default is not None and self.units is None:
#    1496             self.set_units(default)
#
# c:\anaconda3\envs\traineeship\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     113         # default_units->axis_info->convert
#     114         if axis.units is None:
# --> 115             axis.set_units(UnitData(data))
#     116         else:
#     117             axis.units.update(data)
#
# c:\anaconda3\envs\traineeship\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     179         self._counter = itertools.count()
#     180         if data is not None:
# --> 181             self.update(data)
#     182
#     183     @staticmethod
#
# c:\anaconda3\envs\traineeship\lib\site-packages\matplotlib\category.py in update(self, data)
#     216             # OrderedDict just iterates over unique values in data.
#     217             if not isinstance(val, (str, bytes)):
# --> 218                 raise TypeError("{val!r} is not a string".format(val=val))
#     219             if convertible:
#     220                 # this will only be called so long as convertible is True.
#
# TypeError: 98 is not a string

# %%
df.drop(labels='Age', axis=1, inplace=True)  # dropping the Age column as it is heavily polluted
df.dropna()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-cbd2afd5f187> in <module>
# ----> 1 df.drop(labels='Age', axis=1, inplace=True)  # dropping the Age column as it is heavily polluted
#       2 df.dropna()
#
# c:\anaconda3\envs\traineeship\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# c:\anaconda3\envs\traineeship\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# c:\anaconda3\envs\traineeship\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# c:\anaconda3\envs\traineeship\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['Age'] not found in axis"

# %% [markdown]
# Drop the columns where at least one element is missing

# %%
df.dropna(axis='columns')

# %% [markdown]
# Drop the rows where all elements are missing.

# %%
df.dropna(how='all')

# %% [markdown]
# Keep only the rows with at least 2 non-NA values.

# %%
df.dropna(thresh=2)

# %% [markdown]
# Define in which columns to look for missing values.

# %%
df.dropna(subset=['name', 'born'])
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %% [markdown]
# Keep the DataFrame with valid entries in the same variable.

# %%
df.dropna(inplace=True)
df  # Notice inplace=True doesn't print the result but stores the result in df
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %% [markdown]
# ## Murders, she wrote

# %% [markdown]
# Below is a big dataset in which there is a lot of data, but also missing  / NaN etc...You can play with this set.
# <br>
# <br>
# - assignment: in read_csv there is an option to deal with NaN values. <br>
# Converting values to NaN values while importing, is a quick option to deal with data. For instance, you might want to convert NULL values to NaN, so you can drop the columns later on.
# <br>
# Check: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html

# %%
data = pd.read_csv('murder.csv', header=0, delimiter = ',') # Depeding on your file, check the delimeter

# %%
data = pd.read_csv('murder.csv', header=0, delimiter = ',', low_memory=False)  # fixed warning

# %%
data.dtypes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e265660bf664> in <module>
# ----> 1 data.dtypes()
#
# NameError: name 'data' is not defined

# %%
data.columns
# Out:
# Index(['Record ID', 'Agency Code', 'Agency Name', 'Agency Type', 'City',
#        'State', 'Year', 'Month', 'Incident', 'Crime Type', 'Crime Solved',
#        'Victim Sex', 'Victim Age', 'Victim Race', 'Victim Ethnicity',
#        'Perpetrator Sex', 'Perpetrator Age', 'Perpetrator Race',
#        'Perpetrator Ethnicity', 'Relationship', 'Weapon', 'Victim Count',
#        'Perpetrator Count', 'Record Source'],
#       dtype='object')

# %%
plt.plot(data['Victim Age'], 'b.')

# %% [markdown]
# Here you see that there are some high values for the age !!

# %%
# Check the maximum Victim Age
data['Victim Age'].max()
# Out:
# 998

# %%
# Check the occurrence
data[data['Victim Age']>=100]['Victim Age'].count()
# Out:
# 974

# %%
# Check the ages >=100 
plt.plot(data[data['Victim Age']>100]['Victim Age'])

# %% [markdown]
# Conclusion: <br>
# What can be concluded on the age 998? Is this a typo or is does this mean that this is actually a NaN? <br>
#
# <b> Assignment 1: solve the issues for 998. Do you drop the values?

# %%
# <your code here>

# %% [markdown]
# <b> Assignment 2: solve the issue for Age (victim, purpetrator = 0) <b>
# <br>Question: how many rows are remaining?

# %%
#<your code here>

# %% [markdown]
# <b> Assignment 3: go over the notebook 03.04-Missing-Values.ipynb

# %% [markdown]
# <b> Assignment 4: Fix the missing (if any) categorical Data

# %%
# hints: categorical data: http://www.stat.yale.edu/Courses/1997-98/101/catdat.htm

# <your code here>

# %% [markdown]
# # Go To: Data exploration OR:
# # Extra material, tips, hints

# %%
data['City']
# Out:
# 0               Anchorage
# 1               Anchorage
# 2               Anchorage
# 3               Anchorage
# 4               Anchorage
# 5               Anchorage
# 6               Anchorage
# 7               Anchorage
# 8               Anchorage
# 9               Anchorage
# 10              Anchorage
# 11              Anchorage
# 12              Anchorage
# 13              Anchorage
# 14              Anchorage
# 15              Anchorage
# 16              Anchorage
# 17                 Juneau
# 18                   Nome
# 19                 Bethel
# 20            North Slope
# 21            North Slope
# 22            North Slope
# 23            North Slope
# 24            North Slope
# 25        Kenai Peninsula
# 26                 Juneau
# 27                 Juneau
# 28                 Juneau
# 29                 Juneau
#                ...
# 638424            Preston
# 638425              Boone
# 638426         Monongalia
# 638427         Monongalia
# 638428               Wood
# 638429             Mercer
# 638430            Braxton
# 638431              Wayne
# 638432              Wayne
# 638433            Webster
# 638434           McDowell
# 638435           McDowell
# 638436              Mingo
# 638437               Wood
# 638438               Wood
# 638439               Wood
# 638440             Albany
# 638441           Campbell
# 638442            Laramie
# 638443            Laramie
# 638444            Laramie
# 638445            Lincoln
# 638446            Natrona
# 638447            Natrona
# 638448            Natrona
# 638449               Park
# 638450           Sheridan
# 638451           Sheridan
# 638452           Sublette
# 638453         Sweetwater
# Name: City, Length: 638454, dtype: object

# %%
data = data.dropna()

# %%
data2_state = data.groupby(['Year', 'State'], as_index = False).agg({ 'Incident': np.size})
data2_state.set_index('Year')
# Out:
#                      State  Incident
# Year
# 1980               Alabama       513
# 1980                Alaska        47
# 1980               Arizona       293
# 1980              Arkansas       214
# 1980            California      3590
# 1980              Colorado       198
# 1980           Connecticut       158
# 1980              Delaware        44
# 1980  District of Columbia       180
# 1980               Florida      1508
# 1980               Georgia       475
# 1980                Hawaii        84
# 1980                 Idaho        30
# 1980              Illinois      1323
# 2016                 Texas  27904862.0
# 2016                  Utah   3044321.0
# 2016               Vermont    623354.0
# 2016              Virginia   8414380.0
# 2016            Washington   7280934.0
# 2016         West Virginia   1828637.0
# 2016             Wisconsin   5772917.0
# 2016               Wyoming    584910.0
#
# [1887 rows x 2 columns]

# %%
Data_State_Year_Murders_Residence = pd.merge(data2_state, inwoners, on=['Year', 'State'])

Data_State_Year_Murders_Residence.head(10)
# Out:
#    Year        State  Incident  Population
# 0  1980      Alabama       513   3893888.0
# 1  1980       Alaska        47    401851.0
# 2  1980      Arizona       293   2718215.0
# 3  1980     Arkansas       214   2286435.0
# 4  1980   California      3590  23667902.0
# 5  1980     Colorado       198   2889964.0
# 6  1980  Connecticut       158   3107576.0
# 7  1980     Delaware        44    594338.0
# 8  1980      Florida      1508   9746324.0
# 9  1980      Georgia       475   5463105.0

# %%
a= pd.read_csv('Inwoners.csv', header=0, delimiter = ';', index_col = 'Year')
b =pd.read_csv('statemurder.csv', header=0, delimiter = ';', index_col = 'Year')

# %%
a
# Out:
#                      State  Population
# Year
# 1980               Alabama   3893888.0
# 1980                Alaska    401851.0
# 1980               Arizona   2718215.0
# 1980              Arkansas   2286435.0
# 1980            California  23667902.0
# 1980              Colorado   2889964.0
# 1980           Connecticut   3107576.0
# 1980              Delaware    594338.0
# 1980  District of Columbia    638333.0
# 1980               Florida   9746324.0
# 1980               Georgia   5463105.0
# 1980                Hawaii    964691.0
# 1980                 Idaho    943935.0
# 1980              Illinois  11426518.0
# 1980               Indiana   5490224.0
# 1980                  Iowa   2913808.0
# 1980                Kansas   2363679.0
# 1980              Kentucky   3660777.0
# 1980             Louisiana   4205900.0
# 1980                 Maine   1124660.0
# 1980              Maryland   4216975.0
# 1980         Massachusetts   5737037.0
# 1980              Michigan   9262078.0
# 1980             Minnesota   4075970.0
# 1980           Mississippi   2520638.0
# 1980              Missouri   4916686.0
# 1980               Montana    786690.0
# 1980              Nebraska   1569825.0
# 1980                Nevada    800493.0
# 1980         New Hampshire    920610.0
# ...                    ...         ...
# 2016         Massachusetts   6823721.0
# 2016              Michigan   9933445.0
# 2016             Minnesota   5525050.0
# 2016           Mississippi   2985415.0
# 2016              Missouri   6091176.0
# 2016               Montana   1038656.0
# 2016              Nebraska   1907603.0
# 2016                Nevada   2939254.0
# 2016         New Hampshire   1335015.0
# 2016            New Jersey   8978416.0
# 2016            New Mexico   2085432.0
# 2016              New York  19836286.0
# 2016        North Carolina  10156689.0
# 2016          North Dakota    755548.0
# 2016                  Ohio  11622554.0
# 2016              Oklahoma   3921207.0
# 2016                Oregon   4085989.0
# 2016          Pennsylvania  12787085.0
# 2016          Rhode Island   1057566.0
# 2016        South Carolina   4959822.0
# 2016          South Dakota    861542.0
# 2016             Tennessee   6649404.0
# 2016                 Texas  27904862.0
# 2016                  Utah   3044321.0
# 2016               Vermont    623354.0
# 2016              Virginia   8414380.0
# 2016            Washington   7280934.0
# 2016         West Virginia   1828637.0
# 2016             Wisconsin   5772917.0
# 2016               Wyoming    584910.0
#
# [1887 rows x 2 columns]

# %%
a.columns
# Out:
# Index(['State', 'Population'], dtype='object')

# %%
a.stack
# Out:
# <bound method DataFrame.stack of                      State  Population
# Year
# 1980               Alabama   3893888.0
# 1980                Alaska    401851.0
# 1980               Arizona   2718215.0
# 1980              Arkansas   2286435.0
# 1980            California  23667902.0
# 1980              Colorado   2889964.0
# 1980           Connecticut   3107576.0
# 1980              Delaware    594338.0
# 1980  District of Columbia    638333.0
# 1980               Florida   9746324.0
# 1980               Georgia   5463105.0
# 1980                Hawaii    964691.0
# 1980                 Idaho    943935.0
# 1980              Illinois  11426518.0
# 1980               Indiana   5490224.0
# 1980                  Iowa   2913808.0
# 1980                Kansas   2363679.0
# 1980              Kentucky   3660777.0
# 1980             Louisiana   4205900.0
# 1980                 Maine   1124660.0
# 1980              Maryland   4216975.0
# 1980         Massachusetts   5737037.0
# 1980              Michigan   9262078.0
# 1980             Minnesota   4075970.0
# 1980           Mississippi   2520638.0
# 1980              Missouri   4916686.0
# 1980               Montana    786690.0
# 1980              Nebraska   1569825.0
# 1980                Nevada    800493.0
# 1980         New Hampshire    920610.0
# ...                    ...         ...
# 2016         Massachusetts   6823721.0
# 2016              Michigan   9933445.0
# 2016             Minnesota   5525050.0
# 2016           Mississippi   2985415.0
# 2016              Missouri   6091176.0
# 2016               Montana   1038656.0
# 2016              Nebraska   1907603.0
# 2016                Nevada   2939254.0
# 2016         New Hampshire   1335015.0
# 2016            New Jersey   8978416.0
# 2016            New Mexico   2085432.0
# 2016              New York  19836286.0
# 2016        North Carolina  10156689.0
# 2016          North Dakota    755548.0
# 2016                  Ohio  11622554.0
# 2016              Oklahoma   3921207.0
# 2016                Oregon   4085989.0
# 2016          Pennsylvania  12787085.0
# 2016          Rhode Island   1057566.0
# 2016        South Carolina   4959822.0
# 2016          South Dakota    861542.0
# 2016             Tennessee   6649404.0
# 2016                 Texas  27904862.0
# 2016                  Utah   3044321.0
# 2016               Vermont    623354.0
# 2016              Virginia   8414380.0
# 2016            Washington   7280934.0
# 2016         West Virginia   1828637.0
# 2016             Wisconsin   5772917.0
# 2016               Wyoming    584910.0
#
# [1887 rows x 2 columns]>

# %%
data['Weapon'].unique()
# Out:
# array(['Blunt Object', 'Strangulation', 'Unknown', 'Rifle', 'Knife',
#        'Firearm', 'Shotgun', 'Fall', 'Handgun', 'Drowning', 'Suffocation',
#        'Explosives', 'Fire', 'Drugs', 'Gun', 'Poison'], dtype=object)

# %% [markdown]
# Group the guns into one categorie

# %%
data['Weapon']=np.where(data['Weapon'] =='Shotgun', 'Gun', data['Weapon'])
data['Weapon']=np.where(data['Weapon'] =='Handgun', 'Gun', data['Weapon'])
data['Weapon']=np.where(data['Weapon'] =='Rifle', 'Gun', data['Weapon'])

# %%
data['Weapon'].unique()
# Out:
# array(['Blunt Object', 'Strangulation', 'Unknown', 'Gun', 'Knife',
#        'Firearm', 'Fall', 'Drowning', 'Suffocation', 'Explosives', 'Fire',
#        'Drugs', 'Poison'], dtype=object)

# %% [markdown]
# # Data exploration

# %% [markdown]
# What else can you find / clean?

# %%
# <your code here>
