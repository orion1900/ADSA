# %%
#Open the file back and read the contents
f=open('Murder 400 rows.csv', "r")
     #   if f.mode == 'r': 
     #     contents =f.read()
     #     print contents
     #or, readlines reads the individual line into a list
fl =f.readlines()

for x in fl:
 print(x)
# Out:
# Record ID,Agency Code,Agency Name,Agency Type,City,State,Year,Month,Incident,Crime Type,Crime Solved,Victim Sex,Victim Age,Victim Race,Victim Ethnicity,Perpetrator Sex,Perpetrator Age,Perpetrator Race,Perpetrator Ethnicity,Relationship,Weapon,Victim Count,Perpetrator Count,Record Source
#
# 1,AK00101,Anchorage,Municipal Police,Anchorage,Alaska,1980,January,1,Murder or Manslaughter,Yes,Male,14,Native American/Alaska Native,Unknown,Male,15,Native American/Alaska Native,Unknown,Acquaintance,Blunt Object,0,0,FBI
#
# 2,AK00101,Anchorage,Municipal Police,Anchorage,Alaska,1980,March,1,Murder or Manslaughter,Yes,Male,43,White,Unknown,Male,42,White,Unknown,Acquaintance,Strangulation,0,0,FBI
#
# 3,AK00101,Anchorage,Municipal Police,Anchorage,Alaska,1980,March,2,Murder or Manslaughter,No,Female,30,Native American/Alaska Native,Unknown,Unknown,0,Unknown,Unknown,Unknown,Unknown,0,0,FBI
#
# ...

# %%
x
# Out:
# '400,AL03102,Gadsden,Municipal Police,Etowah,Alabama,1980,September,2,Murder or Manslaughter,No,Male,24,Black,Unknown,Unknown,0,Unknown,Unknown,Unknown,Firearm,0,0,FBI'

# %%
x.strip()
# Out:
# '400,AL03102,Gadsden,Municipal Police,Etowah,Alabama,1980,September,2,Murder or Manslaughter,No,Male,24,Black,Unknown,Unknown,0,Unknown,Unknown,Unknown,Firearm,0,0,FBI'

# %% [markdown]
# Strings can be split into a list of substrings with split. By default, Python will use a blank space as a delimiter, which is useful for splitting a sentence into individual words: <br>
# https://www.linode.com/docs/development/python/string-manipulation-python-3/

# %%
y=x.split(',')
print(x)
# Out:
# 400,AL03102,Gadsden,Municipal Police,Etowah,Alabama,1980,September,2,Murder or Manslaughter,No,Male,24,Black,Unknown,Unknown,0,Unknown,Unknown,Unknown,Firearm,0,0,FBI

# %%
print(y)
# Out:
# ['400', 'AL03102', 'Gadsden', 'Municipal Police', 'Etowah', 'Alabama', '1980', 'September', '2', 'Murder or Manslaughter', 'No', 'Male', '24', 'Black', 'Unknown', 'Unknown', '0', 'Unknown', 'Unknown', 'Unknown', 'Firearm', '0', '0', 'FBI']

# %%
y[0]
# Out:
# '400'

# %%
with open('Murder 400 rows.csv') as f:
    line = f.readline()

# %%
line

# %%
with open('Murder 400 rows.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        print(row)

csvFile.close()

# %%
with open('Murder 400 rows.csv', 'r') as f:
    data = (line for line in f)
    data_2 = data_2.join(data)
f.close()

# %%
# ?data_2

# %%
data_2

# %%
import  pandas as pd


pd.read_fwf(data_2)

# %%
import pandas as pd

# %%
a = pd.read_csv("Objects.csv", delimiter = ';')

# %%
a['Name']
# Out:
# 0                                Any
# 1                                  x
# 2                           FW3_eth0
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                Net_218.153.204.138
# 8                 Net_170.55.195.101
# 9                  Net_126.58.234.69
# 10    Net_VLAN_2019_136.78.237.88_28
# 11                          intranet
# 12                     gobal-Finance
# 13                    global-NationX
# 14                     global-DevMgt
# 15                    application_1a
# 16                    application_1b
# 17                       prod_clstr1
# 18                       prod_clstr2
# 19                   prod_clstr2_VIP
# 20                               FW3
# 21                               FW4
# 22                          FW1_vrrp
# 23                       time-writer
# 24           services.checkpoint.com
# ...

# %%
b = pd.read_csv("Rules.csv", delimiter = ';')

# %%
b = b.dropna()

# %%
#b.merge(a[b.Source], left_on='Source', right = 'Name', how='inner')
pd.merge(b, a, how='inner', left_on='Source', right_on = 'Name')
# Out:
#             Source              Destination           Service  Action  \
# 0    gobal-Finance                      Any  accounting-ports  accept
# 1   global-NationX                      Amy     block-NationX    deny
# 2    global-DevMgt                      Any   stats-gathering  accept
# 3   application_1a              prod_clstr2               Any  accept
# 4      prod_clstr1                      Any               ssh  accept
# 5         intranet              prod_clstr2               Any  accept
# 6      prod_clstr2                 intranet      FW1-services  accept
# 7  prod_clstr2_VIP  services.checkpoint.com             https  accept
# 8         FW1_vrrp  services.checkpoint.com               Any    drop
# 9         FW3_eth0                      Any               Any  accept
#
#               Name     Type      IP Address          Netmask  \
# 0    gobal-Finance  network  46.218.106.179    255.255.254.0
# 1   global-NationX  network      74.6.0.175    255.255.255.0
# ...

# %%
b
# Out:
#              Source              Destination               Service  Action
# 0        global-Mgt                      Any  administration-ports  accept
# 2     gobal-Finance                      Any      accounting-ports  accept
# 4    global-NationX                      Amy         block-NationX    deny
# 6     global-DevMgt                      Any       stats-gathering  accept
# 9    application_1a              prod_clstr2                   Any  accept
# 12      prod_clstr1                      Any                   ssh  accept
# 15         intranet              prod_clstr2                   Any  accept
# 19      prod_clstr2                 intranet          FW1-services  accept
# 23  prod_clstr2_VIP  services.checkpoint.com                 https  accept
# 31         FW1_vrrp  services.checkpoint.com                   Any    drop
# 34         FW3_eth0                      Any                   Any  accept
